# %%
#EDA (Explor data analystics) visualizing the data using the numpy,pandas,matplot lib,pandas we need to understand the how data is explorting using the graphs and histograms and barplot and pairplot

#Data pre-processing means removing the unwanted data and removing the null values
#filling with the different stategy mean,median,mode,forward filla and backward fill and fillna and dropna
# in the data set we remove the unwanted data and make the useful data to client that is the main goal of the data pre-processing
#work in the real world scenarios

# %%
import pandas as pd

a=pd.read_csv(r"C:\Users\HP\Desktop\python projects\loan_data_set.csv")
a
#Just reading the csv file using the pandas and the data set is stored in the' a ' variable
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
a.info
a.describe()
a.isnull()
a.dropna()
a.fillna
a.notnull
a.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
a['CoapplicantIncome'].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
a['Credit_History'].value_counts().plot(kind='pie',autopct="%0.2f%%",title="CREDIT HISTORY")
# Out:
# <Axes: title={'center': 'CREDIT HISTORY'}, ylabel='count'>

# %%
a['Married'].value_counts().plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
a['LoanAmount'].value_counts().plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
a['Married'].value_counts().plot(kind="pie",autopct="%0.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
a['Dependents'].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Dependents'>

# %%
a['ApplicantIncome'].value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
a['Loan_Status'].value_counts().plot(kind="pie")

#In the process loan approvel people are more
# Out:
# <Axes: ylabel='count'>

# %%
# !pip install seaborn

import seaborn as rk


rk.barplot(x='Married',y='Loan_Status',data=a)
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# <Axes: xlabel='Married', ylabel='Loan_Status'>

# %%
rk.violinplot(x='Married',y='Loan_Status',data=a)
# Out:
# <Axes: xlabel='Married', ylabel='Loan_Status'>

# %%
rk.clustermap(x='Married',y='Loan_Status',data=a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 rk.clustermap(x='Married',y='Loan_Status',data=a)
#
# File c:\Users\HP\Desktop\python projects\healthcareproject\Lib\site-packages\seaborn\matrix.py:1258, in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1250     raise RuntimeError("clustermap requires scipy to be available")
#    1252 plotter = ClusterGrid(data, pivot_kws=pivot_kws, figsize=figsize,
#    1253                       row_colors=row_colors, col_colors=col_colors,
#    1254                       z_score=z_score, standard_scale=standard_scale,
#    1255                       mask=mask, dendrogram_ratio=dendrogram_ratio,
# ...

# %%
a.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
rk.boxplot(x='Self_Employed',y='ApplicantIncome',data=a)
# Out:
# <Axes: xlabel='Self_Employed', ylabel='ApplicantIncome'>

# %%
rk.catplot(x='Self_Employed',y='ApplicantIncome',data=a)

# %%
rk.dogplot()

# %%
rk.lineplot(x="LoanAmount",y="Loan_Amount_Term",data=a)
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Loan_Amount_Term'>

# %%
rk.pointplot(x="Loan_Amount_Term",y="Loan_Status",data=a)
# Out:
# <Axes: xlabel='Loan_Amount_Term', ylabel='Loan_Status'>

# %%
a.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
rk.boxenplot(x="Loan_Amount_Term",y="Loan_Status",data=a)
# Out:
# <Axes: xlabel='Loan_Amount_Term', ylabel='Loan_Status'>

# %%
rk.boxplot(x="Loan_Amount_Term",y="Loan_Status",data=a)
# Out:
# <Axes: xlabel='Loan_Amount_Term', ylabel='Loan_Status'>

# %%
rk.kdeplot(data=a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 rk.kdeplot(data=a)
#
# NameError: name 'rk' is not defined

# %%
a.dtypes
a.isnull().drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
a
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
a.isnull
# Out:
# <bound method DataFrame.isnull of       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
a.rename_axis(columns="Ramakrishna is a up coming data scientist")
# Out:
# Ramakrishna is a up coming data scientist   Loan_ID  Gender Married  \
# 0                                          LP001002    Male      No
# 1                                          LP001003    Male     Yes
# 2                                          LP001005    Male     Yes
# 3                                          LP001006    Male     Yes
# 4                                          LP001008    Male      No
# ..                                              ...     ...     ...
# 609                                        LP002978  Female      No
# 610                                        LP002979    Male     Yes
# 611                                        LP002983    Male     Yes
# 612                                        LP002984    Male     Yes
# 613                                        LP002990  Female      No
#
# Ramakrishna is a up coming data scientist Dependents     Education  \
# 0                                                  0      Graduate
# ...

# %%
a.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a.shape
#
# NameError: name 'a' is not defined

# %%
a.value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
a.Dependents.backfill
a.Dependents.mean
# Out:
# <bound method Series.mean of 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 609     0
# 610    3+
# 611     1
# 612     2
# 613     0
# Name: Dependents, Length: 614, dtype: object>

# %%
a
a.dropna
a['LoanAmount'].dropna(inplace=True)
print(a)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
a.dropna(inplace=True)

print(a)
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes           2      Graduate            No
# 2    LP001005    Male     Yes           2      Graduate           Yes
# 3    LP001006    Male     Yes           2  Not Graduate            No
# 4    LP001008    Male      No           2      Graduate            No
# 5    LP001011    Male     Yes           2      Graduate           Yes
# ..        ...     ...     ...         ...           ...           ...
# 609  LP002978  Female      No           2      Graduate            No
# 610  LP002979    Male     Yes           2      Graduate            No
# 611  LP002983    Male     Yes           2      Graduate            No
# 612  LP002984    Male     Yes           2      Graduate            No
# 613  LP002990  Female      No           2      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
a.to_csv('a.csv',index=False)
#a.to_excel(a.to_excel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a.to_csv('a.csv',index=False)
#       2 #a.to_excel(a.to_excel)
#
# NameError: name 'a' is not defined

# %%
a.to_csv('a.csv',index=False)

print(a)

0['Dependents']=1
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002    Male      No           2      Graduate            No
# 1    LP001003    Male     Yes           2      Graduate            No
# 2    LP001005    Male     Yes           2      Graduate           Yes
# 3    LP001006    Male     Yes           2  Not Graduate            No
# 4    LP001008    Male      No           2      Graduate            No
# ..        ...     ...     ...         ...           ...           ...
# 609  LP002978  Female      No           2      Graduate            No
# 610  LP002979    Male     Yes           2      Graduate            No
# 611  LP002983    Male     Yes           2      Graduate            No
# 612  LP002984    Male     Yes           2      Graduate            No
# 613  LP002990  Female      No           2      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a['Dependents'].replace(2,inplace='True')
#       2 a
#
# NameError: name 'a' is not defined

# %%
a['Dependents'].fillna
a['Dependents'].bfill
# Out:
# <bound method NDFrame.bfill of 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 609     0
# 610    3+
# 611     1
# 612     2
# 613     0
# Name: Dependents, Length: 614, dtype: object>
