# %%
import pandas as pd




a=pd.read_csv(r"C:\Users\HP\Desktop\python projects\healthcareproject\Walmart.csv")

a
# Out:
#       Store       Date1        Date  Weekly_Sales  Holiday_Flag  Temperature  \
# 0         1  05-02-2010    2-5-2010    1643690.90             0        42.31
# 1         1  12-02-2010   2-12-2010    1641957.44             1        38.51
# 2         1  19-02-2010   2-19-2010    1611968.17             0        39.93
# 3         1  26-02-2010   2-26-2010    1409727.59             0        46.63
# 4         1  05-03-2010    3-5-2010    1554806.68             0        46.50
# ...     ...         ...         ...           ...           ...          ...
# 6430     45  28-09-2012   9-28-2012     713173.95             0        64.88
# 6431     45  05-10-2012   10-5-2012     733455.07             0        64.89
# 6432     45  12-10-2012  10-12-2012     734464.36             0        54.47
# 6433     45  19-10-2012  10-19-2012     718125.53             0        56.47
# 6434     45  26-10-2012  10-26-2012     760281.43             0        58.85
#
#       Fuel_Price         CPI  Unemployment
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date1         6435 non-null   object
#  2   Date          6435 non-null   object
#  3   Weekly_Sales  6435 non-null   float64
#  4   Holiday_Flag  6435 non-null   int64
#  5   Temperature   6435 non-null   float64
#  6   Fuel_Price    6435 non-null   float64
#  7   CPI           6435 non-null   float64
#  8   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 452.6+ KB

# %%
a.isna().sum()
# Out:
# Store           0
# Date1           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
a
# Out:
#       Store       Date1        Date  Weekly_Sales  Holiday_Flag  Temperature  \
# 0         1  05-02-2010    2-5-2010    1643690.90             0        42.31
# 1         1  12-02-2010   2-12-2010    1641957.44             1        38.51
# 2         1  19-02-2010   2-19-2010    1611968.17             0        39.93
# 3         1  26-02-2010   2-26-2010    1409727.59             0        46.63
# 4         1  05-03-2010    3-5-2010    1554806.68             0        46.50
# ...     ...         ...         ...           ...           ...          ...
# 6430     45  28-09-2012   9-28-2012     713173.95             0        64.88
# 6431     45  05-10-2012   10-5-2012     733455.07             0        64.89
# 6432     45  12-10-2012  10-12-2012     734464.36             0        54.47
# 6433     45  19-10-2012  10-19-2012     718125.53             0        56.47
# 6434     45  26-10-2012  10-26-2012     760281.43             0        58.85
#
#       Fuel_Price         CPI  Unemployment
# ...

# %%
# a.drop("Date", axis='columns')

# %%
import seaborn as sns


b =a[['Store','Weekly_Sales', 'Holiday_Flag', 'Temperature',
       'Fuel_Price', 'CPI', 'Unemployment']]
sns.heatmap(b,annot=True)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

x = a['Store']
y = a['Weekly_Sales']
plt.figure(figsize=(15,5))
plt.title('Weekly Sales by Department')
plt.xlabel('Departments')
plt.ylabel('Weekly Sales')
plt.scatter(x,y)
plt.show()

# %%
a
# Out:
#       Store       Date1        Date  Weekly_Sales  Holiday_Flag  Temperature  \
# 0         1  05-02-2010    2-5-2010    1643690.90             0        42.31
# 1         1  12-02-2010   2-12-2010    1641957.44             1        38.51
# 2         1  19-02-2010   2-19-2010    1611968.17             0        39.93
# 3         1  26-02-2010   2-26-2010    1409727.59             0        46.63
# 4         1  05-03-2010    3-5-2010    1554806.68             0        46.50
# ...     ...         ...         ...           ...           ...          ...
# 6430     45  28-09-2012   9-28-2012     713173.95             0        64.88
# 6431     45  05-10-2012   10-5-2012     733455.07             0        64.89
# 6432     45  12-10-2012  10-12-2012     734464.36             0        54.47
# 6433     45  19-10-2012  10-19-2012     718125.53             0        56.47
# 6434     45  26-10-2012  10-26-2012     760281.43             0        58.85
#
#       Fuel_Price         CPI  Unemployment
# ...

# %%
a.columns
a = a[['Store','Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
       'Fuel_Price', 'CPI', 'Unemployment']]

a
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1    2-5-2010    1643690.90             0        42.31       2.572
# 1         1   2-12-2010    1641957.44             1        38.51       2.548
# 2         1   2-19-2010    1611968.17             0        39.93       2.514
# 3         1   2-26-2010    1409727.59             0        46.63       2.561
# 4         1    3-5-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45   9-28-2012     713173.95             0        64.88       3.997
# 6431     45   10-5-2012     733455.07             0        64.89       3.985
# 6432     45  10-12-2012     734464.36             0        54.47       4.000
# 6433     45  10-19-2012     718125.53             0        56.47       3.969
# 6434     45  10-26-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
a.loc[a['Weekly_Sales']<=0]


a.loc[a['Weekly_Sales']>=0]
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1    2-5-2010    1643690.90             0        42.31       2.572
# 1         1   2-12-2010    1641957.44             1        38.51       2.548
# 2         1   2-19-2010    1611968.17             0        39.93       2.514
# 3         1   2-26-2010    1409727.59             0        46.63       2.561
# 4         1    3-5-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45   9-28-2012     713173.95             0        64.88       3.997
# 6431     45   10-5-2012     733455.07             0        64.89       3.985
# 6432     45  10-12-2012     734464.36             0        54.47       4.000
# 6433     45  10-19-2012     718125.53             0        56.47       3.969
# 6434     45  10-26-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
a.sort_values(by='Weekly_Sales',ascending=False).head(5)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1905     14  12-24-2010    3818686.45             0        30.59       3.141
# 2763     20  12-24-2010    3766687.43             0        25.17       3.141
# 1333     10  12-24-2010    3749057.69             0        57.06       3.236
# 527       4  12-23-2011    3676388.98             0        35.92       3.103
# 1762     13  12-24-2010    3595903.20             0        34.90       2.846
#
#              CPI  Unemployment
# 1905  182.544590         8.724
# 2763  204.637673         7.484
# 1333  126.983581         9.003
# 527   129.984548         5.143
# 1762  126.983581         7.795

# %%
a["Date"] = pd.to_datetime(a["Date"]) # convert to datetime
a['Date']

a['Date1'] = a['Date'].dt.strftime('%m/%d/%Y')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4456\532281197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a["Date"] = pd.to_datetime(a["Date"]) # convert to datetime

# %%
a['Date']
# Out:
# 0      2010-02-05
# 1      2010-02-12
# 2      2010-02-19
# 3      2010-02-26
# 4      2010-03-05
#           ...
# 6430   2012-09-28
# 6431   2012-10-05
# 6432   2012-10-12
# 6433   2012-10-19
# 6434   2012-10-26
# Name: Date, Length: 6435, dtype: datetime64[ns]

# %%
a["Date"] = pd.to_datetime(a["Date"]) 
a['month'] =a['Date'].dt.month 
a['year'] =a['Date'].dt.year

# %%
monthly_sales = pd.pivot_table(a, values = "Weekly_Sales", columns = "year", index = "month")
monthly_sales.plot()
# Out:
# <Axes: xlabel='month'>

# %%
import seaborn as sns

fig = sns.barplot(x='month', y='Weekly_Sales', data=a)

# %%
train_data = a[:int(0.7*(len(a)))] # taking train part
test_data = a[int(0.7*(len(a))):] # taking test part

target = "Weekly_Sales"
used_cols = [c for c in a.columns.to_list() if c not in [target]] # all columns except weekly sales

X_train = train_data[used_cols]
X_test = test_data[used_cols]
y_train = train_data[target]
y_test = test_data[target]

# %%
temp = pd.pivot_table(a, values = "Weekly_Sales", index= "Temperature")
temp.plot()
# Out:
# <Axes: xlabel='Temperature'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error
from math import sqrt

# Simulating AR(1) Process (for demonstration) with autocorrelation
np.random.seed(42)
n = 200  # length of time series
phi = 0.7  # AR(1) coefficient
epsilon = np.random.randn(n)  # Random noise (white noise)

# AR(1) process: Y_t = phi * Y_(t-1) + error_t
data = np.zeros(n)
for t in range(1, n):
    data[t] = phi * data[t-1] + epsilon[t]

# Plot the time series data
plt.figure(figsize=(10, 6))
plt.plot(data, label='Simulated AR(1) Data')
plt.title('Simulated AR(1) Process')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# ARIMA(p, d, q) model
# For demonstration, using ARIMA(1, 1, 1) (p=1, d=1, q=1)
# Note: d=1 for differencing to make series stationary

# Fit ARIMA model with order (p, d, q)
arima_model = sm.tsa.ARIMA(data, order=(1, 1, 1))  # ARIMA(1, 1, 1)
arima_model_fitted = arima_model.fit()

# Get the fitted values (predictions)
predictions = arima_model_fitted.predict(start=2, end=n-1)

# Plot the ACF and PACF plots to analyze autocorrelations
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
plot_acf(data, lags=20, ax=ax1)
plot_pacf(data, lags=20, ax=ax2)
plt.suptitle('ACF and PACF Plots (Simulated AR(1) Process)', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# Plot Original vs Predicted (from ARIMA model)
plt.figure(figsize=(10, 6))
plt.plot(data, label='Original Data', color='blue')
plt.plot(range(2, n), predictions, label='Predicted Data', color='red', linestyle='--')
plt.title('Original vs Predicted Data (ARIMA(1,1,1))')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# Compute RMSE (Root Mean Squared Error) between original and predicted data
# We compare the original values starting from time 2 since ARIMA(1,1,1) model needs differencing
rmse = sqrt(mean_squared_error(data[2:], predictions))
print(f'RMSE: {rmse}')
# Out:
# RMSE: 0.9387399850017908

# %%
! pip install pandas numpy matplotlib scikit-learn statsmodels pmdarima

# %%
a
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1         1 2010-02-12    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-03-05    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment       Date1  month  year
# ...

# %%
a['Date'] = pd.to_datetime(a['Date'])

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
#  8   Date1         6435 non-null   object
#  9   month         6435 non-null   int32
#  10  year          6435 non-null   int32
# dtypes: datetime64[ns](1), float64(5), int32(2), int64(2), object(1)
# memory usage: 502.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder


lb=LabelEncoder()


a['Date']=lb.fit_transform(a['Date'])

# %%
import pandas as pd

# Example DataFrame
data = a['Date']
df = pd.DataFrame(data)

# Convert 'date' to datetime
a['Date'] = pd.to_datetime(a['Date'][0])

import pandas as pd

timestamp = pd.Timestamp(a['Date1'][0])  # Convert to Timestamp
timestamp_value = timestamp.timestamp()  # Convert to the number of seconds since the Unix epoch
print(float(timestamp_value))  # You can now safely convert to float




x=a[['Store','Holiday_Flag','Temperature','Fuel_Price','CPI','Unemployment']]


y=a[['Weekly_Sales']]
# Out:
# 1265328000.0

# %%
from sklearn.preprocessing import OneHotEncoder

from sklearn.ensemble import RandomForestRegressor


from sklearn.pipeline import make_pipeline

from sklearn.preprocessing import RobustScaler

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import train_test_split



x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
pipe = Pipeline([('scaler', StandardScaler()), ('model', RandomForestRegressor())])



pipe.fit(x_train,y_train)
# Out:
# c:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model', RandomForestRegressor())])

# %%
rk=pipe.score(x_test,y_test)

print(rk*100)
# Out:
# 93.25563791626124

# %%
h=pipe.predict(x_test)

# %%
time_series=pd.DataFrame(h,columns=['predicted_weekly_sales'])

time_series
# Out:
#       predicted_weekly_sales
# 0               1.304866e+06
# 1               1.205336e+06
# 2               5.286289e+05
# 3               5.185120e+05
# 4               7.657605e+05
# ...                      ...
# 1282            4.393804e+05
# 1283            4.436959e+05
# 1284            7.839049e+05
# 1285            1.218683e+06
# 1286            9.537029e+05
#
# [1287 rows x 1 columns]

# %%
import seaborn as sns


sns.kdeplot(data=h,fill='True')
# Out:
# <Axes: ylabel='Density'>

# %%
import matplotlib.pyplot as plt


plt.plot(h)
