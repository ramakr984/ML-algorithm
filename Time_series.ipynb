# %%
import pandas as pd

time_series=pd.read_excel(r"C:\Users\HP\Desktop\Timeseries_lags.xlsx")

time_series
# Out:
#     Unnamed: 0              Unnamed: 1 Unnamed: 2  Months  lag1  lag2  lag3  \
# 0          NaN  Consider monthly sales        Jan       1   NaN   NaN   NaN
# 1          NaN                     NaN        Feb       2   1.0   NaN   NaN
# 2          NaN                     NaN        Mar       3   2.0   1.0   NaN
# 3          NaN                     NaN        Apr       4   3.0   2.0   1.0
# 4          NaN                     NaN        May       5   4.0   3.0   2.0
# 5          NaN                     NaN        Jun       6   5.0   4.0   3.0
# 6          NaN                     NaN        Jul       7   6.0   5.0   4.0
# 7          NaN                     NaN        Aug       8   7.0   6.0   5.0
# 8          NaN                     NaN        Sep       9   8.0   7.0   6.0
# 9          NaN                     NaN        Oct      10   9.0   8.0   7.0
# 10         NaN                     NaN        Nov      11  10.0   9.0   8.0
# ...

# %%
time_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   0 non-null      float64
#  1   Unnamed: 1   1 non-null      object
#  2   Unnamed: 2   12 non-null     object
#  3   Months       24 non-null     int64
#  4   lag1         11 non-null     float64
#  5   lag2         10 non-null     float64
#  6   lag3         9 non-null      float64
#  7   lag6         6 non-null      float64
#  8   lag12        12 non-null     float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  0 non-null      float64
#  12  Months.1     12 non-null     object
#  13  lag1.1       11 non-null     object
#  14  Unnamed: 14  0 non-null      float64
#  15  Months.2     13 non-null     object
#  16  lag2.1       10 non-null     object
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder



lb=LabelEncoder()



time_series['Months.2']=lb.fit_transform(time_series['Months.2'])

# %%
time_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   0 non-null      float64
#  1   Unnamed: 1   1 non-null      object
#  2   Unnamed: 2   12 non-null     object
#  3   Months       24 non-null     int64
#  4   lag1         11 non-null     float64
#  5   lag2         10 non-null     float64
#  6   lag3         9 non-null      float64
#  7   lag6         6 non-null      float64
#  8   lag12        12 non-null     float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  0 non-null      float64
#  12  Months.1     12 non-null     object
#  13  lag1.1       11 non-null     object
#  14  Unnamed: 14  0 non-null      float64
#  15  Months.2     24 non-null     int64
#  16  lag2.1       10 non-null     object
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
! pip install sarimaxRI

# %%
from statsmodels.tsa.arima.model import ARIMA


# Slice the DataFrame to exclude the last 30 rows for train
train_data,test_data = time_series[:-30],time_series[-30:]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA() #ARMA
model_fit = model.fit()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[48], line 3
#       1 from statsmodels.tsa.arima_model import ARIMA
# ----> 3 model = ARIMA() #ARMA
#       4 model_fit = model.fit()
#
# File c:\Users\HP\Desktop\python projects\healthcareproject\Lib\site-packages\statsmodels\tsa\arima_model.py:45, in ARIMA.__init__(self, *args, **kwargs)
#      44 def __init__(self, *args, **kwargs):
# ---> 45     super().__init__(*args, **kwargs)
#
# File c:\Users\HP\Desktop\python projects\healthcareproject\Lib\site-packages\statsmodels\tsa\arima_model.py:29, in ARMA.__init__(self, *args, **kwargs)
#      28 def __init__(self, *args, **kwargs):
# ---> 29     raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# ...
