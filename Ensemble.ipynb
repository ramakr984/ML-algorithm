# %%
import pandas as pd



a=pd.read_csv(r"C:\Users\HP\Desktop\python projects\healthcareproject\train.csv")

a
# Out:
#             id  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0            0   55         165          60       81.0             0.5
# 1            1   70         165          65       89.0             0.6
# 2            2   20         170          75       81.0             0.4
# 3            3   35         180          95      105.0             1.5
# 4            4   30         165          60       80.5             1.5
# ...        ...  ...         ...         ...        ...             ...
# 159251  159251   40         155          45       69.0             1.5
# 159252  159252   50         155          75       82.0             1.0
# 159253  159253   40         160          50       66.0             1.5
# 159254  159254   50         165          75       92.0             1.2
# 159255  159255   40         145          45       76.4             1.0
#
#         eyesight(right)  hearing(left)  hearing(right)  systolic  ...  HDL  \
# ...

# %%
print(a.shape)
# Out:
# (159256, 24)

# %%
a.columns
# Out:
# Index(['id', 'age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)',
#        'eyesight(right)', 'hearing(left)', 'hearing(right)', 'systolic',
#        'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride',
#        'HDL', 'LDL', 'hemoglobin', 'Urine protein', 'serum creatinine', 'AST',
#        'ALT', 'Gtp', 'dental caries', 'smoking'],
#       dtype='object')

# %%
x=a[['id', 'age', 'height(cm)', 'weight(kg)', 'waist(cm)', 'eyesight(left)',
       'eyesight(right)', 'hearing(left)', 'hearing(right)', 'systolic',
       'relaxation', 'fasting blood sugar', 'Cholesterol', 'triglyceride',
       'HDL', 'LDL', 'hemoglobin', 'Urine protein', 'serum creatinine', 'AST',
       'ALT', 'Gtp', 'dental caries']]



y=a[['smoking']]



from sklearn.model_selection import train_test_split


X_train,X_test,y_train,y_test=train_test_split(x,y,train_size=0.5,test_size=0.3)

# %%
from sklearn.model_selection import train_test_split 

X_train,X_test,y_train,y_test=train_test_split(x,y,train_size=0.8,test_size=0.2,random_state=100)

# %%
from sklearn.ensemble import RandomForestClassifier


rf=RandomForestClassifier(criterion='entropy',max_depth=12,max_features=1,max_leaf_nodes=13,random_state=10)


rf.fit(X_train,y_train)
# Out:
# c:\Users\HP\Desktop\python projects\healthcareproject\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(criterion='entropy', max_depth=12, max_features=1,
#                        max_leaf_nodes=13, random_state=10)

# %%
import pickle

with open('krishna.pickle','wb') as file:
    pickle.dump(rf,file)

# %%
y_predict=rf.predict(X_train)

# %%
l=rf.score(X_train,y_train)

print(l*100)
# Out:
# 73.47885466704342

# %%
! pip install xgboost
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.ensemble import BaggingRegressor


bags=BaggingRegressor(estimator=rf,max_features=12,max_samples=9)

bags.fit(X_train,y_train)
# Out:
# c:\Users\HP\Desktop\python projects\healthcareproject\Lib\site-packages\sklearn\ensemble\_bagging.py:581: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return column_or_1d(y, warn=True)
# BaggingRegressor(estimator=RandomForestClassifier(criterion='entropy',
#                                                   max_depth=12, max_features=1,
#                                                   max_leaf_nodes=13,
#                                                   random_state=10),
#                  max_features=12, max_samples=9)

# %%
import pickle
with open('krishna1.pickle','wb') as file:
    pickle.dump(bags,file)

# %%
baging_predict=bags.predict(X_test)

baging_predict
# Out:
# array([0.1, 0.3, 0. , ..., 0. , 0. , 0.4])

# %%
p=bags.score(X_train,y_train)

print(p*100)
# Out:
# -15.366916274449638

# %%
import xgboost as xgb

hello=xgb.XGBRegressor(objective='binary:logistic',random_state=56,alpha=0.1,reg_lambda=1)

# %%
hello.fit(X_train,y_train)
# Out:
# XGBRegressor(alpha=0.1, base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
with open('krishna3.pickle','wb') as file:
    pickle.dump(hello,file)

# %%
hello.predict(X_train)
# Out:
# array([0.42971352, 0.7301864 , 0.01092588, ..., 0.00280117, 0.03227612,
#        0.01430798], dtype=float32)

# %%
k=hello.score(X_train,y_train)

# %%
print(k*100)
# Out:
# 49.57816004753113

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
# from sklearn.tree import DecisionTree
from sklearn.neighbors import KNeighborsClassifier


# we implemented the all the algorithm from here we used voting for the best fit
s=SVC(probability=True, kernel='linear', random_state=42 )
dt=DecisionTreeClassifier(random_state=24)
knn=KNeighborsClassifier(n_neighbors=5)


vc=VotingClassifier(estimators=[('s',s),('dt',dt),('knn',knn)],voting='soft',weights=[1,1,1])

vc.fit(X_train,y_train)
# Out:
# c:\Users\HP\Desktop\python projects\healthcareproject\Lib\site-packages\sklearn\preprocessing\_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\HP\Desktop\python projects\healthcareproject\Lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
with open('krishna.pickle','wb') as file:
    pickle.dump(vc,file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 with open('krishna.pickle','wb') as file:
# ----> 2     pickle.dump(vc,file)
#
# NameError: name 'vc' is not defined

# %%
import pickle

pickle.dump(rf,"krishna.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pickle
# ----> 3 pickle.dump(rf,"krishna.pkl")
#
# NameError: name 'rf' is not defined
