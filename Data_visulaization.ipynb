# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install kagglehub
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("uciml/student-alcohol-consumption")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Ramakrishna\.cache\kagglehub\datasets\uciml\student-alcohol-consumption\versions\2

# %%
import pandas as hello

print(path)
# Out:
# C:\Users\Ramakrishna\.cache\kagglehub\datasets\uciml\student-alcohol-consumption\versions\2

# %%
hello=pd.read_csv(r"C:\Users\Ramakrishna\Desktop\python\processed_data2.csv")

hello

#Read the dataset using the pandas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 hello=pd.read_csv(r"C:\Users\Ramakrishna\Desktop\python\processed_data2.csv")
#       3 hello
#       5 #Read the dataset using the pandas
#
# NameError: name 'pd' is not defined

# %%
import matplotlib.pyplot as rk

c['phone_brand'].value_counts().plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 import matplotlib.pyplot as rk
# ----> 3 c['phone_brand'].value_counts().plot(kind="bar")
#
# NameError: name 'c' is not defined

# %%
# !pip install matplot
# Out:
# ...
#      ---------------------------------------- 0.0/167.0 kB ? eta -:--:--
#      ------- ------------------------------- 30.7/167.0 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 167.0/167.0 kB 2.5 MB/s eta 0:00:00
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/78.6 kB ? eta -:--:--
#      ---------------------------------------- 78.6/78.6 kB 4.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
# ...

# %%
# !pip install seaborn as good
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

k=pd.read_csv(r"C:\Users\Ramakrishna\Desktop\python\processed_data2.csv")

k
# Out:
#      phone_brand               phone_model       store  price_usd  storage  \
# 0          apple       Apple iPhone 16 Pro   Amazon DE    1357.55      256
# 1          apple       Apple iPhone 16 Pro   Amazon DE    1492.55      512
# 2          apple       Apple iPhone 16 Pro   Amazon DE    1705.32     1000
# 3          apple   Apple iPhone 16 Pro Max   Amazon DE    1564.92      512
# 4          apple      Apple iPhone 12 mini   Amazon DE     247.32      128
# ...          ...                       ...         ...        ...      ...
# 1703      xiaomi     Xiaomi Redmi Note 10S  AliExpress     156.00      128
# 1704      xiaomi     Xiaomi Redmi Note 10S  AliExpress     145.35      128
# 1705      xiaomi  Xiaomi Redmi Note 11 Pro  AliExpress     161.00      128
# 1706      xiaomi      Xiaomi 11 Lite 5G NE  AliExpress     266.66      128
# 1707         zte     ZTE nubia Red Magic 6  AliExpress     515.00      128
#
# ...
