# %%
import pandas as pd

a=pd.read_csv(r"C:\Users\HP\Desktop\python projects\healthcareproject\advertising.csv")
a
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
import matplotlib.pyplot as mp


a['TV'].value_counts().plot(kind="hist",title="TV")
# Out:
# <Axes: title={'center': 'TV'}, ylabel='Frequency'>

# %%
import seaborn as sns

sns.kdeplot(a['Newspaper'])
# Out:
# <Axes: xlabel='Newspaper', ylabel='Density'>

# %%
sns.kdeplot(a['Radio'])
# Out:
# <Axes: xlabel='Radio', ylabel='Density'>

# %%
sns.kdeplot(a['Radio'])
# Out:
# <Axes: xlabel='Radio', ylabel='Density'>

# %%
import matplotlib.pyplot as mp


a['TV'].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %%
import seaborn as sns

import matplotlib.pyplot as plt

fig,axes=plt.subplots(nrows=1,ncols=3,figsize=(10,15))
  
sns.boxplot(a[["TV"]],ax=axes[0])
sns.boxplot(a[["Radio"]],ax=axes[1])
sns.boxplot(a[["Newspaper"]],ax=axes[2])
# Out:
# <Axes: >

# %%
import seaborn as sns

import matplotlib.pyplot as plt

sns.boxplot(data=a['TV'])
# Out:
# <Axes: ylabel='TV'>

# %%
sns.boxplot(data=a['Radio'])
# Out:
# <Axes: ylabel='Radio'>

# %%
# sns.boxplot(data=a['Newspaper'])


# # Q1 =  a['Newspaper'].quantile(0.25)
# # Q3 = a['Newspaper'].quantile(0.75)
# # IQR = Q3 - Q1


# a[(a['Newspaper'] < Q1-1.5*IQR ) | (a['Newspaper'] > Q3+1.5*IQR)]['Newspaper']

a['Newspaper']>100
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Name: Newspaper, Length: 200, dtype: bool

# %%
import seaborn as sns

sns.histplot(data=a['TV'],bins=10,kde="True")
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
#QQ plot(quantile plot quantile plot)

import scipy.stats as st


st.probplot(a["TV"],dist="norm",plot=plt)
# Out:
# ((array([-2.70069508, -2.39117927, -2.21476595, -2.08844273, -1.98865134,
#          -1.90545091, -1.83366817, -1.77025272, -1.7132485 , -1.66132288,
#          -1.61352545, -1.56915347, -1.52767212, -1.48866446, -1.45179889,
#          -1.41680716, -1.38346902, -1.35160134, -1.32105008, -1.29168444,
#          -1.26339229, -1.23607681, -1.20965371, -1.18404921, -1.1591983 ,
#          -1.13504337, -1.11153314, -1.08862177, -1.06626803, -1.04443478,
#          -1.02308837, -1.00219826, -0.9817366 , -0.96167793, -0.94199891,
#          -0.9226781 , -0.90369573, -0.88503353, -0.86667459, -0.84860322,
#          -0.83080482, -0.8132658 , -0.79597346, -0.77891592, -0.76208206,
#          -0.74546144, -0.72904425, -0.71282124, -0.69678371, -0.68092342,
#          -0.6652326 , -0.64970389, -0.63433029, -0.61910517, -0.60402223,
#          -0.58907547, -0.57425918, -0.55956789, -0.5449964 , -0.53053972,
#          -0.51619308, -0.50195192, -0.48781183, -0.47376862, -0.45981823,
# ...

# %%
from sklearn.linear_model import LinearRegression


regressor=LinearRegression()

regressor.fit(a[["TV"]],a["Radio"])
# Out:
# LinearRegression()

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\HP\Desktop\python projects\healthcareproject\advertising.csv",verbose=True)
df
# Out:
# Tokenization took: 0.00 ms
# Type conversion took: 0.00 ms
# Parser memory cleanup took: 0.00 ms
# C:\Users\HP\AppData\Local\Temp\ipykernel_13984\844329222.py:3: FutureWarning: The 'verbose' keyword in pd.read_csv is deprecated and will be removed in a future version.
#   df=pd.read_csv(r"C:\Users\HP\Desktop\python projects\healthcareproject\advertising.csv",verbose=True)
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
200
# Out:
# 200

# %%
df.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
x = df[['TV', 'Radio', 'Newspaper']]
y = df[["Sales"]]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.50,random_state=100)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (100, 3)
# (100, 3)
# (100, 1)
# (100, 1)

# %%
from sklearn.linear_model import LinearRegression

# lr = LinearRegression()
# lr.fit(x_train,y_train)


# lr.predict(x_test)



hello=LinearRegression()

hello.fit(x_train,y_train)
hello.predict(x_test)
# Out:
# array([[ 9.2280238 ],
#        [21.00150957],
#        [16.51762948],
#        [20.277216  ],
#        [21.76921515],
#        [16.17596351],
#        [13.5151066 ],
#        [15.35618137],
#        [20.93558228],
#        [21.08725318],
#        [12.16077144],
#        [20.93462479],
#        [ 8.02473391],
#        [16.79933725],
#        [10.37447673],
#        [ 9.83189395],
#        [16.27365828],
#        [14.59203377],
#        [17.18020712],
#        [12.52856601],
#        [18.55284278],
#        [12.0744341 ],
#        [20.56529526],
#        [17.83576474],
#        [16.7434767 ],
#        [21.62435608],
#        [20.26500927],
#        [10.72114357],
#        [19.09408967],
#        [14.75550954],
#        [13.05088247],
#        [ 8.86407596],
#        [12.07077067],
#        [16.64820513],
#        [ 8.23271105],
#        [13.95283499],
#        [ 9.82212796],
#        [14.20903233],
#        [16.77842334],
#        [17.3151982 ],
#        [19.04054969],
# ...

# %%
predict = hello.predict(x_train)
predict


predict=hello.predict(x_test)

print(predict)
# Out:
# [[ 9.2280238 ]
#  [21.00150957]
#  [16.51762948]
#  [20.277216  ]
#  [21.76921515]
#  [16.17596351]
#  [13.5151066 ]
#  [15.35618137]
#  [20.93558228]
#  [21.08725318]
#  [12.16077144]
#  [20.93462479]
#  [ 8.02473391]
#  [16.79933725]
#  [10.37447673]
#  [ 9.83189395]
#  [16.27365828]
#  [14.59203377]
#  [17.18020712]
#  [12.52856601]
#  [18.55284278]
#  [12.0744341 ]
#  [20.56529526]
#  [17.83576474]
#  [16.7434767 ]
#  [21.62435608]
#  [20.26500927]
#  [10.72114357]
#  [19.09408967]
#  [14.75550954]
#  [13.05088247]
#  [ 8.86407596]
#  [12.07077067]
#  [16.64820513]
#  [ 8.23271105]
#  [13.95283499]
#  [ 9.82212796]
#  [14.20903233]
#  [16.77842334]
#  [17.3151982 ]
#  [19.04054969]
#  [15.43538773]
#  [15.84172958]
#  [16.91670724]
#  [12.92617419]
#  [10.39196779]
#  [10.61871051]
#  [20.95001977]
#  [10.06200479]
#  [ 6.66453653]
#  [17.94606158]
#  [18.21044852]
#  [12.52495405]
#  [16.25701266]
#  [18.99058686]
#  [11.24471112]
#  [ 5.71515375]
#  [ 9.84007613]
# ...

# %%
x_test[0:10]
# Out:
#         TV  Radio  Newspaper
# 126    7.8   38.9       50.6
# 104  238.2   34.3        5.3
# 99   135.2   41.7       45.9
# 92   217.7   33.5       59.0
# 111  241.7   38.0       23.2
# 167  206.8    5.2       19.4
# 116  139.2   14.3       25.6
# 96   197.6    3.5        5.9
# 52   216.4   41.7       39.6
# 69   216.8   43.9       27.2

# %%
predict[99]
# Out:
# array([15.51857661])

# %%
train_score = hello.score(x_train,y_train)
print("training_score = ",round(train_score*100))
# Out:
# training_score =  91

# %%
test_score = hello.score(x_test,y_test)
print(f"test_score = ",round(test_score*100,2))
# Out:
# test_score =  87.57

# %%
bias = test_score - train_score

round(bias*100,2)
# Out:
# -3.54

# %%
print(x_test)

print(y_test)

print(x_train)

print(y_train)
# Out:
#         TV  Radio  Newspaper
# 126    7.8   38.9       50.6
# 104  238.2   34.3        5.3
# 99   135.2   41.7       45.9
# 92   217.7   33.5       59.0
# 111  241.7   38.0       23.2
# ..     ...    ...        ...
# 54   262.7   28.8       15.9
# 25   262.9    3.5       19.5
# 21   237.4    5.1       23.5
# 48   227.2   15.8       49.9
# 9    199.8    2.6       21.2
#
# [100 rows x 3 columns]
#      Sales
# 126    6.6
# 104   20.7
# 99    17.2
# 92    19.4
# 111   21.8
# ..     ...
# 54    20.2
# 25    17.0
# 21    17.5
# 48    19.8
# 9     15.6
#
# [100 rows x 1 columns]
#         TV  Radio  Newspaper
# 23   228.3   16.9       26.2
# 35   290.7    4.1        8.5
# 175  276.9   48.9       41.8
# 50   199.8    3.1       34.6
# 62   239.3   15.5       27.3
# ..     ...    ...        ...
# 87   110.7   40.6       63.2
# 103  187.9   17.2       17.9
# 67   139.3   14.5       10.2
# 24    62.3   12.6       18.3
# 8      8.6    2.1        1.0
#
# [100 rows x 3 columns]
#      Sales
# ...

# %%
a = x_train.iloc[0:5]
a

b = y_train.iloc[0:5]
b

team=print(a+b)
k=b['Sales']="hello"

print(k.isalnum)
# Out:
#      Newspaper  Radio  Sales  TV
# 23         NaN    NaN    NaN NaN
# 35         NaN    NaN    NaN NaN
# 175        NaN    NaN    NaN NaN
# 50         NaN    NaN    NaN NaN
# 62         NaN    NaN    NaN NaN
# <built-in method isalnum of str object at 0x00000220137F9DD0>
# C:\Users\HP\AppData\Local\Temp\ipykernel_13984\1775889239.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k=b['Sales']="hello"

# %%
import numpy as np


c=predict(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 4
#       1 import numpy as np
# ----> 4 c=predict(b)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
y_test[0:1]
# Out:
#      Sales
# 126    6.6

# %%
import numpy as np

d = pd.DataFrame({"TV":[30],"Radio":[20],"Newspaper":[26]})
d.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
# ----> 3 d = pd.DataFrame({"TV":[30],"Radio":[20],"Newspaper":[26]})
#       4 d.values
#
# NameError: name 'pd' is not defined

# %%
# import joblib

# b  = joblib.dump(lr,"project.joblib")

# %%
import joblib

b = joblib.load("project.joblib")

# %%
hello.predict(x)

hello.predict(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 hello.predict(x)
#       3 hello.predict(y)
#
# NameError: name 'hello' is not defined

# %%
from sklearn.linear_model import LogisticRegression

lg=LogisticRegression

lg.fit(x_train,y_train)


y1=lg.predict(y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13984\3305447963.py in ?()
#       1 from sklearn.linear_model import LogisticRegression
#       2
#       3 lg=LogisticRegression
#       4
# ----> 5 lg.fit(x_train,y_train)
#       6
#       7
#       8 y1=lg.predict(y_train)
#
# c:\Users\HP\Desktop\python projects\healthcareproject\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1462                 fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1463             )
#    1464
#    1465             if not global_skip_validation and not partial_fit_and_fitted:
# -> 1466                 estimator._validate_params()
#    1467
#    1468             with config_context(
#    1469                 skip_parameter_validation=(
#
# ...

# %%
from sklearn.naive_bayes import GaussianNB

team=GaussianNB()

team.fit(y_train)


y5=team.predict(y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 5
#       1 from sklearn.naive_bayes import GaussianNB
#       3 team=GaussianNB()
# ----> 5 team.fit(y_train)
#       8 y5=team.predict(y_train)
#
# File c:\Users\HP\Desktop\python projects\healthcareproject\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# TypeError: GaussianNB.fit() missing 1 required positional argument: 'y'
