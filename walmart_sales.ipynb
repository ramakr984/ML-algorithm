# %%
import pandas as pd

a=pd.read_csv("Walmart.csv")

a
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
a.columns

df={'Store':[11], 'Date':['05-02-2050'],  'Holiday_Flag':[1], 'Temperature':[34],'Fuel_Price':[67], 'CPI':[89], 'Unemployment':[90], 'Date_Ordinal':[90]}

df = pd.DataFrame(df)

# %%
a["Date"].nunique()
# Out:
# 143

# %%
a["Date"].unique()
# Out:
# array(['05-02-2010', '12-02-2010', '19-02-2010', '26-02-2010',
#        '05-03-2010', '12-03-2010', '19-03-2010', '26-03-2010',
#        '02-04-2010', '09-04-2010', '16-04-2010', '23-04-2010',
#        '30-04-2010', '07-05-2010', '14-05-2010', '21-05-2010',
#        '28-05-2010', '04-06-2010', '11-06-2010', '18-06-2010',
#        '25-06-2010', '02-07-2010', '09-07-2010', '16-07-2010',
#        '23-07-2010', '30-07-2010', '06-08-2010', '13-08-2010',
#        '20-08-2010', '27-08-2010', '03-09-2010', '10-09-2010',
#        '17-09-2010', '24-09-2010', '01-10-2010', '08-10-2010',
#        '15-10-2010', '22-10-2010', '29-10-2010', '05-11-2010',
#        '12-11-2010', '19-11-2010', '26-11-2010', '03-12-2010',
#        '10-12-2010', '17-12-2010', '24-12-2010', '31-12-2010',
#        '07-01-2011', '14-01-2011', '21-01-2011', '28-01-2011',
#        '04-02-2011', '11-02-2011', '18-02-2011', '25-02-2011',
#        '04-03-2011', '11-03-2011', '18-03-2011', '25-03-2011',
# ...

# %%
a.value_counts().isna()
# Out:
# Store  Date        Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  CPI         Unemployment
# 45     31-12-2010  679156.20     1             29.67        3.179       182.571448  8.724           False
# 1      01-04-2011  1495064.75    0             59.17        3.524       214.837166  7.682           False
#        01-06-2012  1624477.58    0             77.95        3.501       221.747214  7.143           False
# 45     23-03-2012  791835.37     0             59.45        3.900       190.536321  8.424           False
#        23-04-2010  749779.10     0             53.47        2.902       181.677256  8.899           False
#                                                                                                     ...
# 1      02-07-2010  1492418.14    0             80.91        2.669       211.223533  7.787           False
#        02-09-2011  1550229.22    0             87.83        3.533       215.797141  7.962           False
# ...

# %%
a['Date'] = pd.to_datetime(a['Date'], format='mixed')

# Convert the 'Date' column to ordinal (days since 01-01-0001)
# a['Date_Ordinal'] = a['Date'].apply(lambda x: x.toordinal())

# %%
a['Date_Ordinal'] = a['Date'].apply(lambda x: x.toordinal())

# %%
a['Date_Ordinal']
# Out:
# 0       733894
# 1       734108
# 2       733822
# 3       733829
# 4       733895
#          ...
# 6430    734774
# 6431    734633
# 6432    734847
# 6433    734795
# 6434    734802
# Name: Date_Ordinal, Length: 6435, dtype: int64

# %%
# a['Date'] = pd.to_datetime(a['Date'],format='mixed')


# a.dtypes
# # Convert the 'Date' column to datetime format
# # df = pd.to_datetime(a['Date'])

# %%
a.isna().value_counts()
# Out:
# Store  Date   Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  CPI    Unemployment  Date_Ordinal
# False  False  False         False         False        False       False  False         False           6435
# Name: count, dtype: int64

# %%
import seaborn as sns

sns.scatterplot(x="Store",y="Unemployment",data=a)
# Out:
# <Axes: xlabel='Store', ylabel='Unemployment'>

# %%
#Q-Q plot


import scipy.stats as st
import matplotlib.pyplot as plt


st.probplot(a['Fuel_Price'],dist="uniform",plot=plt)
# Out:
# ((array([1.07709379e-04, 2.61445932e-04, 4.16837273e-04, ...,
#          9.99583163e-01, 9.99738554e-01, 9.99892291e-01]),
#   array([2.472, 2.513, 2.514, ..., 4.468, 4.468, 4.468])),
#  (np.float64(1.581002921821195),
#   np.float64(2.5681053766962405),
#   np.float64(0.9943054633971252)))

# %%
x=a[['Store','Date_Ordinal','Holiday_Flag','Temperature','Fuel_Price','CPI','Unemployment']]

y=a[['Weekly_Sales']]

print(x)

print(y)
# Out:
#       Store  Date_Ordinal  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1        733894             0        42.31       2.572  211.096358
# 1         1        734108             1        38.51       2.548  211.242170
# 2         1        733822             0        39.93       2.514  211.289143
# 3         1        733829             0        46.63       2.561  211.319643
# 4         1        733895             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45        734774             0        64.88       3.997  192.013558
# 6431     45        734633             0        64.89       3.985  192.170412
# 6432     45        734847             0        54.47       4.000  192.327265
# 6433     45        734795             0        56.47       3.969  192.330854
# 6434     45        734802             0        58.85       3.882  192.308899
#
#       Unemployment
# 0            8.106
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=70)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predict = model.predict(x_test)

# %%
df
df['Date'] = pd.to_datetime(df['Date'], format='mixed')
df['Date_Ordinal'] = df['Date'].apply(lambda x: x.toordinal())
df
# Out:
#    Store       Date  Holiday_Flag  Temperature  Fuel_Price  CPI  Unemployment  \
# 0     11 2050-05-02             1           34          67   89            90
#
#    Date_Ordinal
# 0        748504

# %%
df1 = df[["Store","Date_Ordinal","Holiday_Flag","Temperature","Fuel_Price","CPI","Unemployment"]]
df1
# Out:
#    Store  Date_Ordinal  Holiday_Flag  Temperature  Fuel_Price  CPI  \
# 0     11        748504             1           34          67   89
#
#    Unemployment
# 0            90

# %%
import pandas as pd
df = pd.DataFrame({'Store':[11], 'Date':['05-02-2050'],  'Holiday_Flag':[1], 'Temperature':[34],'Fuel_Price':[67], 'CPI':[89], 'Unemployment':[90], 'Date_Ordinal':[90]})
df
# Out:
#    Store        Date  Holiday_Flag  Temperature  Fuel_Price  CPI  \
# 0     11  05-02-2050             1           34          67   89
#
#    Unemployment  Date_Ordinal
# 0            90            90

# %%
model.predict(df1)
# Out:
# array([[277799.22313701]])

# %%
import joblib
joblib.dump(model,"walmart.joblib")
# Out:
# ['walmart.joblib']

# %%
import joblib
model =joblib.load(r"C:\Users\HP\Desktop\python projects\healthcareproject\walmart.joblib")
model.predict(df1)
# Out:
# array([[277799.22313701]])

# %%
x_test
# Out:
#       Store  Date_Ordinal  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 3352     24        734249             0        46.00       4.061  134.357100
# 3371     24        734177             0        68.14       3.879  136.244097
# 2701     19        734697             0        73.17       3.689  138.263000
# 3297     24        733807             0        45.22       2.957  131.901968
# 1790     13        734356             0        77.30       3.563  129.112500
# ...     ...           ...           ...          ...         ...         ...
# 43        1        733843             0        49.27       2.708  211.607193
# 2744     20        733997             0        75.98       2.805  204.853378
# 257       2        734606             0        68.08       3.891  221.148403
# 2365     17        734347             0        68.59       3.574  129.167710
# 3378     24        734431             0        56.60       3.757  136.501774
#
#       Unemployment
# 3352         8.212
# ...

# %%
from sklearn.metrics import r2_score

r2_score(y_test, predict)
# Out:
# 0.12527435491938144

# %%
model.score(x_train,y_train)
# Out:
# 0.14776036265875292

# %%
import pandas as pd

h=pd.to_datetime(a['Date'],format='time')

print(h)
# Out:
# 0      2010-05-02
# 1      2010-12-02
# 2      2010-02-19
# 3      2010-02-26
# 4      2010-05-03
#           ...
# 6430   2012-09-28
# 6431   2012-05-10
# 6432   2012-12-10
# 6433   2012-10-19
# 6434   2012-10-26
# Name: Date, Length: 6435, dtype: datetime64[ns]

# %%
x=a[['Store','Date','Holiday_Flag','Temperature','Fuel_Price','CPI','Unemployment']]

y=a[['Weekly_Sales']]


from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.50,random_state=100)

print(x)

print(y)
# Out:
#       Store       Date  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1 2010-05-02             0        42.31       2.572  211.096358
# 1         1 2010-12-02             1        38.51       2.548  211.242170
# 2         1 2010-02-19             0        39.93       2.514  211.289143
# 3         1 2010-02-26             0        46.63       2.561  211.319643
# 4         1 2010-05-03             0        46.50       2.625  211.350143
# ...     ...        ...           ...          ...         ...         ...
# 6430     45 2012-09-28             0        64.88       3.997  192.013558
# 6431     45 2012-05-10             0        64.89       3.985  192.170412
# 6432     45 2012-12-10             0        54.47       4.000  192.327265
# 6433     45 2012-10-19             0        56.47       3.969  192.330854
# 6434     45 2012-10-26             0        58.85       3.882  192.308899
#
#       Unemployment
# 0            8.106
# 1            8.106
# ...

# %%
from sklearn.linear_model import LinearRegression




regressor=LinearRegression()

regressor.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[81], line 8
#       1 from sklearn.linear_model import LinearRegression
#       6 regressor=LinearRegression()
# ----> 8 regressor.fit(x_train,y_train)
#
# File c:\Users\HP\Desktop\python projects\healthcareproject\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\HP\Desktop\python projects\healthcareproject\Lib\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
# ...
